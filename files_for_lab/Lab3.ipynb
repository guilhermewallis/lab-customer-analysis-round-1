# %%
import pandas as pd

# %% [markdown]
# 1. Read the three files into python as dataframes

# %%
data1 = pd.read_csv("csv_files/file1.csv")
data2 = pd.read_csv("csv_files/file2.csv")
data3 = pd.read_csv("csv_files/file3.csv")

# %% [markdown]
# 2. Show the DataFrame's shape.

# %%
print('data1', data1.shape)
print('data2', data2.shape)
print('data3', data3.shape)
# Out:
# data1 (4008, 11)
# data2 (996, 11)
# data3 (7070, 11)

# %% [markdown]
# 3. Standardize header names

# %%
data1.columns = [col.lower().replace(' ', '_') for col in data1.columns]
data2.columns = [col.lower().replace(' ', '_') for col in data2.columns]
data3.columns = [col.lower().replace(' ', '_') for col in data3.columns]
data3
# Out:
#      customer       state  customer_lifetime_value             education  \
# 0     SA25987  Washington              3479.137523  High School or Below
# 1     TB86706     Arizona              2502.637401                Master
# 2     ZL73902      Nevada              3265.156348              Bachelor
# 3     KX23516  California              4455.843406  High School or Below
# 4     FN77294  California              7704.958480  High School or Below
# ...       ...         ...                      ...                   ...
# 7065  LA72316  California             23405.987980              Bachelor
# 7066  PK87824  California              3096.511217               College
# 7067  TD14365  California              8163.890428              Bachelor
# 7068  UP19263  California              7524.442436               College
# 7069  Y167826  California              2611.836866               College
#
#      gender  income  monthly_premium_auto  number_of_open_complaints  \
# ...

# %% [markdown]
# 4. Rearrange the columns in the dataframe as needed

# %%
print(data1.columns)
print(data2.columns)
print(data3.columns)

data2 = data2[list(data1.columns.values)]
data3.rename(columns = {'state':'st'}, inplace = True)
data3 = data3[list(data1.columns.values)]
# Out:
# Index(['customer', 'st', 'gender', 'education', 'customer_lifetime_value',
#        'income', 'monthly_premium_auto', 'number_of_open_complaints',
#        'policy_type', 'vehicle_class', 'total_claim_amount'],
#       dtype='object')
# Index(['customer', 'st', 'gender', 'education', 'customer_lifetime_value',
#        'income', 'monthly_premium_auto', 'number_of_open_complaints',
#        'total_claim_amount', 'policy_type', 'vehicle_class'],
#       dtype='object')
# Index(['customer', 'state', 'customer_lifetime_value', 'education', 'gender',
#        'income', 'monthly_premium_auto', 'number_of_open_complaints',
#        'policy_type', 'total_claim_amount', 'vehicle_class'],
#       dtype='object')

# %% [markdown]
# 5. Concatenate the three dataframes

# %%
data = pd.concat([data1, data2, data3])

# %% [markdown]
# 6. Which columns are numerical?
# 7. Which columns are categorical?

# %%
display(data.select_dtypes('number'))
#income 	monthly_premium_auto 	total_claim_amount
display(data.select_dtypes('object'))
#customer 	st 	gender 	education 	customer_lifetime_value 	number_of_open_complaints 	policy_type 	vehicle_class
# Out:
#        income  monthly_premium_auto  total_claim_amount
# 0         0.0                1000.0            2.704934
# 1         0.0                  94.0         1131.464935
# 2     48767.0                 108.0          566.472247
# 3         0.0                 106.0          529.881344
# 4     36357.0                  68.0           17.269323
# ...       ...                   ...                 ...
# 7065  71941.0                  73.0          198.234764
# 7066  21604.0                  79.0          379.200000
# 7067      0.0                  85.0          790.784983
# 7068  21941.0                  96.0          691.200000
# 7069      0.0                  77.0          369.600000
#
# [12074 rows x 3 columns]
#      customer          st gender             education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# ...

# %% [markdown]
# 8. Understand the meaning of all columns

# %%
print(data.columns)
# Out:
# Index(['customer', 'st', 'gender', 'education', 'customer_lifetime_value',
#        'income', 'monthly_premium_auto', 'number_of_open_complaints',
#        'policy_type', 'vehicle_class', 'total_claim_amount'],
#       dtype='object')

# %% [markdown]
# Columns:
# customer - customer ID
# st - US state of residence
# gender - customer's gender
# education - level of education of customer
# customer_lifetime_value - total worth of customer
# income - customer's yearly income
# monthly_premium_auto - monthly insurance cost for customer
# number_of_open_complaints - number of ongoing complaints
# policy_type - type of policy (personal/corporate/special)
# vehicle_class - type of vehicle customer owns
# total_claim_amount - total amount paid to customer in claims so far

# %% [markdown]
# 9. Perform the data cleaning operations mentioned so far in class

# %%
#Delete the column education and the number of open complaints from the dataframe.

data = data.drop(['education', 'number_of_open_complaints'], axis=1)
data
# Out:
#      customer          st gender customer_lifetime_value   income  \
# 0     RB50392  Washington    NaN                     NaN      0.0
# 1     QZ44356     Arizona      F              697953.59%      0.0
# 2     AI49188      Nevada      F             1288743.17%  48767.0
# 3     WW63253  California      M              764586.18%      0.0
# 4     GA49547  Washington      M              536307.65%  36357.0
# ...       ...         ...    ...                     ...      ...
# 7065  LA72316  California      M             23405.98798  71941.0
# 7066  PK87824  California      F             3096.511217  21604.0
# 7067  TD14365  California      M             8163.890428      0.0
# 7068  UP19263  California      M             7524.442436  21941.0
# 7069  Y167826  California      M             2611.836866      0.0
#
#       monthly_premium_auto     policy_type  vehicle_class  total_claim_amount
# 0                   1000.0   Personal Auto  Four-Door Car            2.704934
# ...

# %%
#Correct the values in the column customer lifetime value.

data['customer_lifetime_value'] = data['customer_lifetime_value'].str.replace(r'[^0-9]+', '')
data['customer_lifetime_value'] = data['customer_lifetime_value'].astype(float)
data['customer_lifetime_value'] = data['customer_lifetime_value'].fillna(0)
data['customer_lifetime_value'] = data['customer_lifetime_value'] * 100
data['customer_lifetime_value']
# Out:
# C:\Users\grwc9\AppData\Local\Temp\ipykernel_3244\2199282485.py:3: FutureWarning: The default value of regex will change from True to False in a future version.
#   data['customer_lifetime_value'] = data['customer_lifetime_value'].str.replace(r'[^0-9]+', '')
# 0       0.000000e+00
# 1       6.979536e+09
# 2       1.288743e+10
# 3       7.645862e+09
# 4       5.363076e+09
#             ...
# 7065    0.000000e+00
# 7066    0.000000e+00
# 7067    0.000000e+00
# 7068    0.000000e+00
# 7069    0.000000e+00
# Name: customer_lifetime_value, Length: 12074, dtype: float64

# %%
#Check for duplicate rows in the data and remove if any.

print(data.shape) #(12074, 9)
dups = data[data.duplicated()]
print(dups.shape) #(2943, 9)
data = data.drop_duplicates()
print(data.shape) #(9131, 9)
# Out:
# (12074, 9)
# (2943, 9)
# (9131, 9)

# %%
#Filter out the data for customers who have an income of 0 or less.

print(data.shape) #(9131, 9)
data = data[data['income'] > 0]
print(data.shape) #(6837, 9)
# Out:
# (9131, 9)
# (6837, 9)
